# %%
pip install gensim
# Out:
# Requirement already satisfied: gensim in /Users/tayfun/opt/anaconda3/lib/python3.8/site-packages (4.1.2)
# Requirement already satisfied: numpy>=1.17.0 in /Users/tayfun/opt/anaconda3/lib/python3.8/site-packages (from gensim) (1.20.1)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/tayfun/opt/anaconda3/lib/python3.8/site-packages (from gensim) (5.2.1)
# Requirement already satisfied: scipy>=0.18.1 in /Users/tayfun/opt/anaconda3/lib/python3.8/site-packages (from gensim) (1.6.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
import numpy as np
import string
# from operator import itemgetter
from collections import Counter, OrderedDict

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
import nltk
nltk.download('punkt')
nltk.download('stopwords')

from gensim.models.phrases import Phrases, Phraser
from gensim.models import Word2Vec

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from matplotlib import pyplot as plt

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
# Out:
# [nltk_data] Downloading package punkt to /Users/tayfun/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/tayfun/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
wine = pd.read_csv('Data/winemag-data-130k-v2.csv.zip', compression='zip', low_memory=False)

# %%
wine.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
food_review_dataset = pd.read_csv('Reviews.csv')
print(food_review_dataset.shape)
# Out:
# (568454, 10)

# %%
food_review_dataset.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %% [markdown]
# # 1. Training Word Embeddings for Wine Dataset

# %%
wine_reviews_list = list(wine['description'])

# %%
wine_reviews_list[0]
# Out:
# "Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity."

# %%
full_wine_reviews_list = [str(r) for r in wine_reviews_list] # macht aus jedem Wort ein String
full_wine_corpus = ' '.join(full_wine_reviews_list) # full_wine_reviews_list als EIN ZUSAMMENHÄNGENDER String dargestellt 
wine_sentences_tokenized = sent_tokenize(full_wine_corpus) # Eine Liste mit ganzen Sätzen als Einträge.

# %%
print(wine_sentences_tokenized[:2]) # Erste zwei Sätze, also Listeneinträge [0,2)
# Out:
# ['Aromas include tropical fruit, broom, brimstone and dried herb.', "The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity."]

# %%
wine_sentences_tokenized[0]
# Out:
# 'Aromas include tropical fruit, broom, brimstone and dried herb.'

# %%
len(wine_reviews_list)
# Out:
# 129971

# %%
full_wine_reviews_list[0]
# Out:
# "Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity."

# %%
stop_words = set(stopwords.words('english'))

punctuation_table = str.maketrans({key: None for key in string.punctuation})
sno = SnowballStemmer('english') # SnowballStemmer bildet den Stamm eines Wortes. 'english' weil engl. Text

def normalize_text(raw_text):
    try:
        word_list = word_tokenize(raw_text)
        normalized_sentence = []
        for w in word_list:
            try:
                w = str(w)
                lower_case_word = str.lower(w)
                stemmed_word = sno.stem(lower_case_word)
                no_punctuation = stemmed_word.translate(punctuation_table)
                if len(no_punctuation) > 1 and no_punctuation not in stop_words:
                    normalized_sentence.append(no_punctuation)
            except:
                continue
        return normalized_sentence
    except:
        return ''

# %% [markdown]
# Eine Liste, wo jeder Listeneintrag aus den Wortstämmen eines Satzes besteht:

# %%
normalized_wine_sentences = []
for s in wine_sentences_tokenized:
    normalized_text = normalize_text(s)
    normalized_wine_sentences.append(normalized_text)

# %%
normalized_wine_sentences[:5]
# Out:
# [['aroma', 'includ', 'tropic', 'fruit', 'broom', 'brimston', 'dri', 'herb'],
#  ['palat',
#   'nt',
#   'express',
#   'offer',
#   'unripen',
#   'appl',
#   'citrus',
#   'dri',
#   'sage',
#   'alongsid',
#   'brisk',
#   'acid'],
#  ['ripe', 'fruiti', 'wine', 'smooth', 'still', 'structur'],
#  ['firm',
#   'tannin',
#   'fill',
#   'juici',
#   'red',
#   'berri',
#   'fruit',
#   'freshen',
#   'acid'],
#  ['alreadi', 'drinkabl', 'although', 'certain', 'better', '2016']]

# %%
# first, take care of the wine trigrams
wine_bigram_model = Phrases(normalized_wine_sentences, min_count=100)
wine_bigrams = [wine_bigram_model[line] for line in normalized_wine_sentences]
wine_trigram_model = Phrases(wine_bigrams, min_count=50)
phrased_wine_sentences = [wine_trigram_model[line] for line in wine_bigrams]
wine_trigram_model.save('wine_trigrams.pkl')

# %%
wine_trigram_model = Phraser.load('wine_trigrams.pkl')

# %%
wine_trigram_model

# %% [markdown]
# Nun zum wichtigsten Teil: Mit Hilfe der bestehenden Weintheorie, der Arbeit anderer wie Bernard Chen, der Zuordnung von Weindeskriptoren und des Weinrades der UC Davis wurden die 5000 häufigsten Weinbegriffe überprüft, um (i) festzustellen, ob es sich um einen Deskriptor handelt, der durch Blindverkostung abgeleitet werden kann, und (ii) ob sie informativ sind (Urteile wie "lecker" und "großartig" werden nicht als informativ angesehen). Die verbleibenden rund 1000 Deskriptoren wurden dann auf einen normalisierten Deskriptor, eine Kategorie und eine Klasse abgebildet:

# %%
descriptor_mapping = pd.read_csv('descriptor_mapping.csv', encoding='latin1').set_index('raw descriptor')

# %%
descriptor_mapping.shape
# Out:
# (1015, 4)

# %%
descriptor_mapping.head(5)
# Out:
#                     level_3      level_2 level_1      type
# raw descriptor
# abras              abrasive  high_tannin  tannin  nonaroma
# acacia               acacia      flowery  flower     aroma
# acacia_flower        acacia      flowery  flower     aroma
# aciddriven      acid_driven    high_acid    acid  nonaroma
# aggress          aggressive    high_acid    acid  nonaroma

# %%
# index() is an inbuilt function in Python, which searches for a given element from the
# start of the list and returns the lowest index where the element appears
def return_mapped_descriptor(word, mapping):
    if word in list(mapping.index):
        normalized_word = mapping.at[word, 'level_3']
        return normalized_word
    else:
        return word
    
normalized_wine_sentences = []
for sent in phrased_wine_sentences:
    normalized_wine_sentence = []
    for word in sent:
        normalized_word = return_mapped_descriptor(word, descriptor_mapping) # Funktionsaufruf (s.o.)
        normalized_wine_sentence.append(str(normalized_word))
    normalized_wine_sentences.append(normalized_wine_sentence) # append: fügt Element hinzu

# %% [markdown]
# ## Preprocessing Wine Dataset
#
# produce recommendations at the grape variety & subregion level

# %%
variety_mapping = {'Shiraz': 'Syrah', 'Pinot Gris': 'Pinot Grigio', 'Pinot Grigio/Gris': 'Pinot Grigio', 
                   'Garnacha, Grenache': 'Grenache', 'Garnacha': 'Grenache', 'Carmenère': 'Carmenere',
                    'Grüner Veltliner': 'Gruner Veltliner', 'Torrontés': 'Torrontes', 
                   'Rhône-style Red Blend': 'Rhone-style Red Blend', 'Albariño': 'Albarino',
                  'Gewürztraminer': 'Gewurztraminer', 'Rhône-style White Blend': 'Rhone-style White Blend',
                  'Spätburgunder, Pinot Noir': 'Pinot Noir', 'Sauvignon, Sauvignon Blanc': 'Sauvignon Blanc',
                  'Pinot Nero, Pinot Noir': 'Pinot Noir', 'Malbec-Merlot, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                  'Meritage, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Garnacha, Grenache': 'Grenache',
                   'Fumé Blanc': 'Sauvignon Blanc', 'Cabernet Sauvignon-Cabernet Franc, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Cabernet Merlot, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Cabernet Sauvignon-Merlot, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Cabernet Blend, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Malbec-Cabernet Sauvignon, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Merlot-Cabernet Franc, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Merlot-Cabernet Sauvignon, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Cabernet Franc-Merlot, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Merlot-Malbec, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Cabernet, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Primitivo, Zinfandel': 'Zinfandel',
                   'Aragonês, Tempranillo': 'Aragonez, Tempranillo'
                  }

def consolidate_varieties(variety_name):
    if variety_name in variety_mapping:
        return variety_mapping[variety_name]
    else:
        return variety_name

# %%
# copy dataframe and rename the columns:
wine_df_clean = wine.copy()

wine_df_clean = wine_df_clean.rename({'country': 'Country', 'province': 'Province', 'region_1': 'Region', 'region_2': 'Subregion',
                     'variety': 'Variety'}, axis=1)

# %%
wine_df_clean['Variety'] = wine_df_clean['Variety'].apply(consolidate_varieties)

# %%
order_of_geographies = ['Subregion', 'Region', 'Province', 'Country']

# replace any nan values in the geography columns with the word none
def replace_nan_for_zero(value):
    if str(value) == '0' or str(value) == 'nan':
        return 'none'
    else:
        return value

for o in order_of_geographies:
    wine_df_clean[o] = wine_df_clean[o].apply(replace_nan_for_zero)

wine_df_clean.loc[:, order_of_geographies].fillna('none', inplace=True)

# %%
variety_geo = wine_df_clean.groupby(['Variety', 'Country', 'Province', 'Region', 'Subregion']).size().reset_index().rename(columns={0:'count'})
variety_geo_sliced = variety_geo.loc[variety_geo['count'] > 1]

vgeos_df = pd.DataFrame(variety_geo_sliced, columns=['Variety', 'Country', 'Province', 'Region', 'Subregion', 'count']) 
vgeos_df.to_csv('varieties_all_geos.csv')

# %%
wine_df_clean.head()
# Out:
#    Unnamed: 0   Country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           Province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#                 Region          Subregion         taster_name  \
# 0                 Etna               none       Kerin O’Keefe
# 1                 none               none          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore               none  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           Variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2    Pinot Grigio            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
wine_df_clean.drop(['Unnamed: 0','designation', 'points', 'price', 'taster_name', 'taster_twitter_handle', 
                     'winery'], axis=1, inplace=True)

# %%
wine_df_clean.head()
# Out:
#     Country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#             Province               Region          Subregion  \
# 0  Sicily & Sardinia                 Etna               none
# 1              Douro                 none               none
# 2             Oregon    Willamette Valley  Willamette Valley
# 3           Michigan  Lake Michigan Shore               none
# 4             Oregon    Willamette Valley  Willamette Valley
#
#                                                title         Variety
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)    Pinot Grigio
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir

# %%
wine_df_clean.shape
# Out:
# (129971, 7)

# %%
variety_geo_df = pd.read_csv('varieties_all_geos_normalized.csv', index_col=0)

wine_df_merged = pd.merge(left=wine_df_clean, right=variety_geo_df, left_on=['Variety', 'Country', 'Province', 'Region', 'Subregion'],
                         right_on=['Variety', 'Country', 'Province', 'Region', 'Subregion'])

# %%
wine_df_merged.head
# Out:
# <bound method NDFrame.head of             Country                                        description  \
# 0             Italy  Aromas include tropical fruit, broom, brimston...
# 1             Italy  This is a mineral-driven wine from the blacken...
# 2             Italy  Delicate scents of white flower, flint and whi...
# 3             Italy  Subdued aromas of Spanish broom and brimstone ...
# 4             Italy  Cavanera is a white blend produced by one of t...
# ...             ...                                                ...
# 36859     Australia  Dry woody notes reminiscent of sawdust join ap...
# 36860   New Zealand  A rare Marlborough Merlot, this is a superfici...
# 36861  South Africa  Light and easy with a great lift to the green ...
# 36862  South Africa  Fresh, clean and easy with ripe aromas of red ...
# 36863       Germany  Dusty mineral complexities juxtapose luscious ...
#
#                 Province            Region Subregion  \
# 0      Sicily & Sardinia              Etna      none
# 1      Sicily & Sardinia              Etna      none
# 2      Sicily & Sardinia              Etna      none
# 3      Sicily & Sardinia              Etna      none
# 4      Sicily & Sardinia              Etna      none
# ...                  ...               ...       ...
# 36859           Victoria  Central Victoria      none
# 36860        Marlborough              none      none
# 36861          Swartland              none      none
# 36862          Swartland              none      none
# 36863              Pfalz              none      none
#
#                                                    title          Variety  \
# 0                      Nicosia 2013 Vulkà Bianco  (Etna)      White Blend
# 1                     Tenuta delle Terre Nere 2007  Etna      White Blend
# 2          Cantine Valenti 2015 Enrico IV Bianco  (Etna)      White Blend
# 3      Contrada Santo Spirito di Passopisciaro 2012 A...      White Blend
# 4      Firriato 2009 Cavanera Ripa di Scorciavacca  (...      White Blend
# ...                                                  ...              ...
# 36859    Four Sisters 2015 Chardonnay (Central Victoria)       Chardonnay
# 36860  Saint Clair 2010 Rapaura Reserve Merlot (Marlb...           Merlot
# 36861  Riebeek Cellars 2010 Collection Sauvignon Blan...  Sauvignon Blanc
# 36862  Riebeek Cellars 2010 Collection Chardonnay (Sw...       Chardonnay
# 36863             Pflüger 2015 Biodynamite White (Pfalz)      White Blend
#
#        count                 geo_normalized
# 0         64  Sicily, Southern Italy, Italy
# 1         64  Sicily, Southern Italy, Italy
# 2         64  Sicily, Southern Italy, Italy
# 3         64  Sicily, Southern Italy, Italy
# 4         64  Sicily, Southern Italy, Italy
# ...      ...                            ...
# 36859      2            Victoria, Australia
# 36860     10       Marlborough, New Zealand
# 36861      3   Coastal Region, South Africa
# 36862      2   Coastal Region, South Africa
# 36863      4                 Pfalz, Germany
#
# [36864 rows x 9 columns]>

# %%
wine_df_merged.drop(['count'], axis=1, inplace=True)

# %%
wine_df_merged.head
# Out:
# <bound method NDFrame.head of             Country                                        description  \
# 0             Italy  Aromas include tropical fruit, broom, brimston...
# 1             Italy  This is a mineral-driven wine from the blacken...
# 2             Italy  Delicate scents of white flower, flint and whi...
# 3             Italy  Subdued aromas of Spanish broom and brimstone ...
# 4             Italy  Cavanera is a white blend produced by one of t...
# ...             ...                                                ...
# 36859     Australia  Dry woody notes reminiscent of sawdust join ap...
# 36860   New Zealand  A rare Marlborough Merlot, this is a superfici...
# 36861  South Africa  Light and easy with a great lift to the green ...
# 36862  South Africa  Fresh, clean and easy with ripe aromas of red ...
# 36863       Germany  Dusty mineral complexities juxtapose luscious ...
#
#                 Province            Region Subregion  \
# 0      Sicily & Sardinia              Etna      none
# 1      Sicily & Sardinia              Etna      none
# 2      Sicily & Sardinia              Etna      none
# 3      Sicily & Sardinia              Etna      none
# 4      Sicily & Sardinia              Etna      none
# ...                  ...               ...       ...
# 36859           Victoria  Central Victoria      none
# 36860        Marlborough              none      none
# 36861          Swartland              none      none
# 36862          Swartland              none      none
# 36863              Pfalz              none      none
#
#                                                    title          Variety  \
# 0                      Nicosia 2013 Vulkà Bianco  (Etna)      White Blend
# 1                     Tenuta delle Terre Nere 2007  Etna      White Blend
# 2          Cantine Valenti 2015 Enrico IV Bianco  (Etna)      White Blend
# 3      Contrada Santo Spirito di Passopisciaro 2012 A...      White Blend
# 4      Firriato 2009 Cavanera Ripa di Scorciavacca  (...      White Blend
# ...                                                  ...              ...
# 36859    Four Sisters 2015 Chardonnay (Central Victoria)       Chardonnay
# 36860  Saint Clair 2010 Rapaura Reserve Merlot (Marlb...           Merlot
# 36861  Riebeek Cellars 2010 Collection Sauvignon Blan...  Sauvignon Blanc
# 36862  Riebeek Cellars 2010 Collection Chardonnay (Sw...       Chardonnay
# 36863             Pflüger 2015 Biodynamite White (Pfalz)      White Blend
#
#                       geo_normalized
# 0      Sicily, Southern Italy, Italy
# 1      Sicily, Southern Italy, Italy
# 2      Sicily, Southern Italy, Italy
# 3      Sicily, Southern Italy, Italy
# 4      Sicily, Southern Italy, Italy
# ...                              ...
# 36859            Victoria, Australia
# 36860       Marlborough, New Zealand
# 36861   Coastal Region, South Africa
# 36862   Coastal Region, South Africa
# 36863                 Pfalz, Germany
#
# [36864 rows x 8 columns]>

# %%
variety_geos = wine_df_merged.groupby(['Variety', 'geo_normalized']).size()
at_least_n_types = variety_geos[variety_geos > 30].reset_index()

# %%
at_least_n_types
# Out:
#                       Variety                                 geo_normalized  \
# 0    Bordeaux-style Red Blend                   Coastal Region, South Africa
# 1    Bordeaux-style Red Blend                       Graves, Bordeaux, France
# 2    Bordeaux-style Red Blend                   Libournais, Bordeaux, France
# 3    Bordeaux-style Red Blend                        Medoc, Bordeaux, France
# 4    Bordeaux-style Red Blend                             Mendoza, Argentina
# 5    Bordeaux-style Red Blend                       Southwest France, France
# 6    Bordeaux-style Red Blend                                  Virginia, USA
# 7              Cabernet Franc             Anjou-Saumar, Loire Valley, France
# 8              Cabernet Franc                    Finger Lakes, New York, USA
# 9              Cabernet Franc                             Mendoza, Argentina
# 10             Cabernet Franc                 Touraine, Loire Valley, France
# 11             Cabernet Franc                                  Virginia, USA
# 12         Cabernet Sauvignon        Cachapoal Valley, Central Valley, Chile
# 13         Cabernet Sauvignon                   Coastal Region, South Africa
# 14         Cabernet Sauvignon        Colchagua Valley, Central Valley, Chile
# 15         Cabernet Sauvignon                    Finger Lakes, New York, USA
# 16         Cabernet Sauvignon                                Galilee, Israel
# 17         Cabernet Sauvignon            Maipo Valley, Central Valley, Chile
# 18         Cabernet Sauvignon            Maule Valley, Central Valley, Chile
# 19         Cabernet Sauvignon                             Mendoza, Argentina
# 20         Cabernet Sauvignon            Rapel Valley, Central Valley, Chile
# 21         Cabernet Sauvignon                     South Australia, Australia
# 22         Cabernet Sauvignon                  Tuscany, Central Italy, Italy
# 23         Cabernet Sauvignon                   Western Australia, Australia
# 24                 Chardonnay             Alto Adige, Northeast Italy, Italy
# 25                 Chardonnay                             Beaujolais, France
# 26                 Chardonnay                            Burgenland, Austria
# 27                 Chardonnay     Casablanca Valley, Aconcagua Region, Chile
# 28                 Chardonnay                      Chablis, Burgundy, France
# 29                 Chardonnay                              Champagne, France
# 30                 Chardonnay                   Coastal Region, South Africa
# 31                 Chardonnay        Colchagua Valley, Central Valley, Chile
# 32                 Chardonnay             Cote Chalonnaise, Burgundy, France
# 33                 Chardonnay               Cote de Beaune, Burgundy, France
# 34                 Chardonnay                    Finger Lakes, New York, USA
# 35                 Chardonnay  Friuli-Venezia Giulia, Northeast Italy, Italy
# 36                 Chardonnay               Lombardy, Northwest Italy, Italy
# 37                 Chardonnay            Maipo Valley, Central Valley, Chile
# 38                 Chardonnay            Maule Valley, Central Valley, Chile
# 39                 Chardonnay                             Mendoza, Argentina
# 40                 Chardonnay           San Antonio, Aconcagua Region, Chile
# 41                 Chardonnay                  Sicily, Southern Italy, Italy
# 42                 Chardonnay                     South Australia, Australia
# 43                 Chardonnay                 Trento, Northeast Italy, Italy
# 44                 Chardonnay                            Victoria, Australia
# 45                 Chardonnay                                  Virginia, USA
# 46                 Chardonnay                   Western Australia, Australia
# 47                 Chardonnay                 Willamette Valley, Oregon, USA
# 48                      Gamay                             Beaujolais, France
# 49                   Grenache                 Aragon, Northeast Spain, Spain
# 50                   Grenache                Navarra, Northeast Spain, Spain
# 51                   Grenache                     South Australia, Australia
# 52           Gruner Veltliner                            Burgenland, Austria
# 53           Gruner Veltliner                      Niederosterreich, Austria
# 54                     Malbec        Colchagua Valley, Central Valley, Chile
# 55                     Malbec                             Mendoza, Argentina
# 56                     Malbec                               Salta, Argentina
# 57                     Malbec                            San Juan, Argentina
# 58                     Malbec                       Southwest France, France
# 59                     Merlot                   Coastal Region, South Africa
# 60                     Merlot        Colchagua Valley, Central Valley, Chile
# 61                     Merlot            Maipo Valley, Central Valley, Chile
# 62                     Merlot            Maule Valley, Central Valley, Chile
# 63                     Merlot                             Mendoza, Argentina
# 64                     Merlot            Rapel Valley, Central Valley, Chile
# 65                     Merlot                  Tuscany, Central Italy, Italy
# 66                     Merlot                                  Virginia, USA
# 67                   Nebbiolo               Lombardy, Northwest Italy, Italy
# 68                   Nebbiolo               Piedmont, Northwest Italy, Italy
# 69               Pinot Grigio                                 Alsace, France
# 70               Pinot Grigio             Alto Adige, Northeast Italy, Italy
# 71               Pinot Grigio                    Finger Lakes, New York, USA
# 72               Pinot Grigio  Friuli-Venezia Giulia, Northeast Italy, Italy
# 73               Pinot Grigio                       Marlborough, New Zealand
# 74               Pinot Grigio                 Trento, Northeast Italy, Italy
# 75               Pinot Grigio                 Veneto, Northeast Italy, Italy
# 76               Pinot Grigio                 Willamette Valley, Oregon, USA
# 77                 Pinot Noir                                 Alsace, France
# 78                 Pinot Noir     Casablanca Valley, Aconcagua Region, Chile
# 79                 Pinot Noir                     Central Otago, New Zealand
# 80                 Pinot Noir                   Centre, Loire Valley, France
# 81                 Pinot Noir                              Champagne, France
# 82                 Pinot Noir             Cote Chalonnaise, Burgundy, France
# 83                 Pinot Noir               Cote de Beaune, Burgundy, France
# 84                 Pinot Noir                Cote de Nuits, Burgundy, France
# 85                 Pinot Noir                    Finger Lakes, New York, USA
# 86                 Pinot Noir                       Marlborough, New Zealand
# 87                 Pinot Noir                             Mendoza, Argentina
# 88                 Pinot Noir                      Niederosterreich, Austria
# 89                 Pinot Noir           San Antonio, Aconcagua Region, Chile
# 90                 Pinot Noir                            Victoria, Australia
# 91                 Pinot Noir                         Wairarapa, New Zealand
# 92                 Pinot Noir                 Willamette Valley, Oregon, USA
# 93                   Riesling                                 Alsace, France
# 94                   Riesling                    Finger Lakes, New York, USA
# 95                   Riesling                                  Michigan, USA
# 96                   Riesling                                 Mosel, Germany
# 97                   Riesling                                  Nahe, Germany
# 98                   Riesling                      Niederosterreich, Austria
# 99                   Riesling                                Ontario, Canada
# 100                  Riesling                                 Pfalz, Germany
# 101                  Riesling                              Rheingau, Germany
# 102                  Riesling                           Rheinhessen, Germany
# 103                  Riesling                     South Australia, Australia
# 104                  Riesling                 Willamette Valley, Oregon, USA
# 105                Sangiovese         Emilia-Romagna, Northeast Italy, Italy
# 106                Sangiovese                  Tuscany, Central Italy, Italy
# 107           Sauvignon Blanc     Casablanca Valley, Aconcagua Region, Chile
# 108           Sauvignon Blanc                   Centre, Loire Valley, France
# 109           Sauvignon Blanc            Clear Lake, North Coast, California
# 110           Sauvignon Blanc                   Coastal Region, South Africa
# 111           Sauvignon Blanc        Colchagua Valley, Central Valley, Chile
# 112           Sauvignon Blanc            Maipo Valley, Central Valley, Chile
# 113           Sauvignon Blanc                       Marlborough, New Zealand
# 114           Sauvignon Blanc            Maule Valley, Central Valley, Chile
# 115           Sauvignon Blanc                             Mendoza, Argentina
# 116           Sauvignon Blanc           San Antonio, Aconcagua Region, Chile
# 117           Sauvignon Blanc                     South Australia, Australia
# 118           Sauvignon Blanc                 Touraine, Loire Valley, France
# 119                     Syrah        Cachapoal Valley, Central Valley, Chile
# 120                     Syrah                   Coastal Region, South Africa
# 121                     Syrah        Colchagua Valley, Central Valley, Chile
# 122                     Syrah                                Galilee, Israel
# 123                     Syrah                       Hawke's Bay, New Zealand
# 124                     Syrah            Maipo Valley, Central Valley, Chile
# 125                     Syrah                             Mendoza, Argentina
# 126                     Syrah                  Sicily, Southern Italy, Italy
# 127                     Syrah              Sierra Foothills, California, USA
# 128                     Syrah                     South Australia, Australia
# 129                     Syrah                  Tuscany, Central Italy, Italy
# 130                     Syrah                            Victoria, Australia
# 131                     Syrah                   Western Australia, Australia
# 132               Tempranillo      Castilla and Leon, Northwest Spain, Spain
# 133               Tempranillo       Castilla-La Mancha, Central Spain, Spain
# 134               Tempranillo               La Rioja, Northeast Spain, Spain
# 135                  Viognier                                  Virginia, USA
# 136               White Blend                                 Alsace, France
# 137               White Blend                            Burgenland, Austria
# 138               White Blend              Catalunya, Northeast Spain, Spain
# 139               White Blend  Friuli-Venezia Giulia, Northeast Italy, Italy
# 140               White Blend               La Rioja, Northeast Spain, Spain
# 141               White Blend                  Sicily, Southern Italy, Italy
# 142               White Blend                       Southwest France, France
# 143               White Blend                  Tuscany, Central Italy, Italy
# 144               White Blend                   Umbria, Central Italy, Italy
# 145               White Blend                 Veneto, Northeast Italy, Italy
# 146               White Blend                                  Virginia, USA
#
#         0
# 0      84
# 1      69
# 2     300
# 3     644
# 4      75
# 5      53
# 6      73
# 7      44
# 8     125
# 9      53
# 10    114
# 11    102
# 12     34
# 13    104
# 14    198
# 15     75
# 16     70
# 17    257
# 18     61
# 19    452
# 20     32
# 21    178
# 22     69
# 23     51
# 24     33
# 25     39
# 26     34
# 27    178
# 28    588
# 29    295
# 30     86
# 31     46
# 32     92
# 33    560
# 34    176
# 35     58
# 36     60
# 37     50
# 38     40
# 39    259
# 40     33
# 41     40
# 42    146
# 43     46
# 44     48
# 45    117
# 46     81
# 47    233
# 48    743
# 49    137
# 50     45
# 51     73
# 52     48
# 53    853
# 54     64
# 55   1262
# 56     35
# 57     33
# 58    398
# 59     36
# 60     53
# 61     54
# 62     32
# 63     51
# 64     31
# 65     91
# 66     36
# 67     66
# 68   2663
# 69    455
# 70    118
# 71     53
# 72    259
# 73     39
# 74     43
# 75    139
# 76    266
# 77    131
# 78    140
# 79    123
# 80    112
# 81     72
# 82    118
# 83    479
# 84    489
# 85    102
# 86    264
# 87     52
# 88     41
# 89     53
# 90     72
# 91     75
# 92   1211
# 93    717
# 94    573
# 95     32
# 96   1115
# 97     73
# 98    464
# 99     46
# 100   105
# 101   299
# 102   182
# 103   107
# 104    91
# 105    49
# 106  2138
# 107   203
# 108   512
# 109    80
# 110    74
# 111    41
# 112    33
# 113   466
# 114    50
# 115    62
# 116   122
# 117    32
# 118    67
# 119    33
# 120    87
# 121    73
# 122    37
# 123    42
# 124    41
# 125    50
# 126    54
# 127    55
# 128   455
# 129    86
# 130    68
# 131    36
# 132   500
# 133   129
# 134   629
# 135    59
# 136    31
# 137    36
# 138    47
# 139   115
# 140    74
# 141   183
# 142    48
# 143   105
# 144    72
# 145    96
# 146    34

# %%
wine_df_merged_filtered = pd.merge(wine_df_merged, at_least_n_types, left_on=['Variety', 'geo_normalized'], right_on=['Variety', 'geo_normalized'])

# %%
wine_df_merged_filtered = wine_df_merged_filtered[['title', 'Variety', 'geo_normalized', 'description']]

# %%
wine_df_merged_filtered.head()
# Out:
#                                                title      Variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)  White Blend
# 1                 Tenuta delle Terre Nere 2007  Etna  White Blend
# 2      Cantine Valenti 2015 Enrico IV Bianco  (Etna)  White Blend
# 3  Contrada Santo Spirito di Passopisciaro 2012 A...  White Blend
# 4  Firriato 2009 Cavanera Ripa di Scorciavacca  (...  White Blend
#
#                   geo_normalized  \
# 0  Sicily, Southern Italy, Italy
# 1  Sicily, Southern Italy, Italy
# 2  Sicily, Southern Italy, Italy
# 3  Sicily, Southern Italy, Italy
# 4  Sicily, Southern Italy, Italy
#
#                                          description
# 0  Aromas include tropical fruit, broom, brimston...
# 1  This is a mineral-driven wine from the blacken...
# 2  Delicate scents of white flower, flint and whi...
# 3  Subdued aromas of Spanish broom and brimstone ...
# 4  Cavanera is a white blend produced by one of t...

# %% [markdown]
# The dataframe wine_df_merged_filtered now contains the title of the wine, the variety (which describes the type of grapes used to make the wine (ie White Blend), geographic data regarding where the data is from and a description regarding the wine. Wine varities with a count smaller than 30 were filtered, as well as datasets with incomplete geographic data.

# %% [markdown]
# # Data preprocessing food dataset

# %%
food_review_dataset = pd.read_csv('Reviews.csv')
print(food_review_dataset.shape)
# Out:
# (568454, 10)

# %%
food_reviews_list = list(food_review_dataset['Text'])

# %%
food_reviews_list[:5]
# Out:
# ['I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labrador is finicky and she appreciates this product better than  most.',
#  'Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".',
#  'This is a confection that has been around a few centuries.  It is a light, pillowy citrus gelatin with nuts - in this case Filberts. And it is cut into tiny squares and then liberally coated with powdered sugar.  And it is a tiny mouthful of heaven.  Not too chewy, and very flavorful.  I highly recommend this yummy treat.  If you are familiar with the story of C.S. Lewis\' "The Lion, The Witch, and The Wardrobe" - this is the treat that seduces Edmund into selling out his Brother and Sisters to the Witch.',
#  'If you are looking for the secret ingredient in Robitussin I believe I have found it.  I got this in addition to the Root Beer Extract I ordered (which was good) and made some cherry soda.  The flavor is very medicinal.',
#  'Great taffy at a great price.  There was a wide assortment of yummy taffy.  Delivery was very quick.  If your a taffy lover, this is a deal.']

# %%
full_food_reviews_list = [str(r) for r in food_reviews_list]
full_food_corpus = ' '.join(full_food_reviews_list)
food_sentences_tokenized = sent_tokenize(full_food_corpus)

# %%
print(food_sentences_tokenized[:2])
# Out:
# ['I have bought several of the Vitality canned dog food products and have found them all to be of good quality.', 'The product looks more like a stew than a processed meat and it smells better.']

# %%
normalized_food_sentences = []
for s in food_sentences_tokenized:
    normalized_text = normalize_text(s)
    normalized_food_sentences.append(normalized_text)

# %%
food_bigram_model = Phrases(normalized_food_sentences, min_count=100)
food_bigrams = [food_bigram_model[sent] for sent in normalized_food_sentences]
food_trigram_model = Phrases(food_bigrams, min_count=50)
phrased_food_sentences = [food_trigram_model[sent] for sent in food_bigrams]
food_trigram_model.save('food_trigrams.pkl')

# %%
food_trigram_model = Phraser.load('food_trigrams.pkl')

# %%
aroma_descriptor_mapping = descriptor_mapping.loc[descriptor_mapping['type'] == 'aroma']
normalized_food_sentences = []
for sent in phrased_food_sentences:
    normalized_food_sentence = []
    for word in sent:
        normalized_word = return_mapped_descriptor(word, aroma_descriptor_mapping)
        normalized_food_sentence.append(str(normalized_word))
    normalized_food_sentences.append(normalized_food_sentence)

# %%
normalized_sentences = normalized_wine_sentences + normalized_food_sentences

# %%
wine_word2vec_model = Word2Vec(normalized_sentences, vector_size=300, min_count=8, epochs=15)
print(wine_word2vec_model)

wine_word2vec_model.save('food_word2vec_model.bin')
# Out:
# Word2Vec(vocab=36695, vector_size=300, alpha=0.025)

# %%
wine_word2vec_model = Word2Vec.load("food_word2vec_model.bin")

# %% [markdown]
# # Create vectors for wine

# %%
wine_reviews = list(wine_df_merged_filtered['description'])

descriptor_mapping = pd.read_csv('descriptor_mapping_tastes.csv', encoding='latin1').set_index('raw descriptor')

core_tastes = ['aroma', 'weight', 'sweet', 'acid', 'salt', 'piquant', 'fat', 'bitter']
descriptor_mappings = dict()
for c in core_tastes:
    if c=='aroma':
        descriptor_mapping_filtered=descriptor_mapping.loc[descriptor_mapping['type']=='aroma']
    else:
        descriptor_mapping_filtered=descriptor_mapping.loc[descriptor_mapping['primary taste']==c]
    descriptor_mappings[c] = descriptor_mapping_filtered                                                   
    

def return_descriptor_from_mapping(descriptor_mapping, word, core_taste):
    if word in list(descriptor_mapping.index):
        descriptor_to_return = descriptor_mapping['combined'][word]
        return descriptor_to_return
    else:
        return None

review_descriptors = []
for review in wine_reviews:
    taste_descriptors = []
    normalized_review = normalize_text(review)
    phrased_review = wine_trigram_model[normalized_review]
#     print(phrased_review)
    
    for c in core_tastes:                                                      
        descriptors_only = [return_descriptor_from_mapping(descriptor_mappings[c], word, c) for word in phrased_review]
        no_nones = [str(d).strip() for d in descriptors_only if d is not None]
        descriptorized_review = ' '.join(no_nones)
        taste_descriptors.append(descriptorized_review)
    review_descriptors.append(taste_descriptors)

# %%
print(phrased_review)
# Out:
# ['initi', 'doe_nt', 'distinguish', 'nose', 'deal', 'typic', 'chilean', 'chardonnay', 'aroma', 'corn', 'stalk', 'along', 'warmweath', 'fruit', 'mouth', 'howev', 'miner', 'intens', 'drive', 'acid', 'push', 'flavor', 'oak', 'cinnamon', 'toast', 'bake', 'appl', 'finish', 'fruit', 'fade', 'rather', 'quick', 'vanilla', 'resini', 'oak', 'flavor', 'settl', 'take']

# %% [markdown]
# Now we will take the list of descriptors for each wine and its aroma/nonaroma vectors and compute a TF-IDF weighted embedding for each. We will store the results in a dataframe.

# %%
taste_descriptors = []
taste_vectors = []

for n, taste in enumerate(core_tastes):
    print(taste)
    taste_words = [r[n] for r in review_descriptors]
    
    vectorizer = TfidfVectorizer()
    X = vectorizer.fit(taste_words)
    dict_of_tfidf_weightings = dict(zip(X.get_feature_names(), X.idf_))
        
    wine_review_descriptors = []
    wine_review_vectors = []
    
    for d in taste_words:
        descriptor_count = 0
        weighted_review_terms = []
        terms = d.split(' ')
        for term in terms:
            if term in dict_of_tfidf_weightings.keys():
                tfidf_weighting = dict_of_tfidf_weightings[term]
                try:
                    word_vector = wine_word2vec_model.wv.get_vector(term).reshape(1, 300)
                    weighted_word_vector = tfidf_weighting * word_vector
                    weighted_review_terms.append(weighted_word_vector)
                    descriptor_count += 1
                except:
                    continue
            else:
                continue
        try:
            review_vector = sum(weighted_review_terms)/len(weighted_review_terms)
            review_vector = review_vector[0]
        except:
            review_vector = np.nan
#         terms_and_vec = [terms, review_vector]
        wine_review_vectors.append(review_vector)
        wine_review_descriptors.append(terms)
    
    taste_vectors.append(wine_review_vectors)
    taste_descriptors.append(wine_review_descriptors)
    

taste_vectors_t = list(map(list, zip(*taste_vectors)))
taste_descriptors_t = list(map(list, zip(*taste_descriptors)))

review_vecs_df = pd.DataFrame(taste_vectors_t, columns=core_tastes)

columns_taste_descriptors = [a + '_descriptors' for a in core_tastes]
review_descriptors_df = pd.DataFrame(taste_descriptors_t, columns=columns_taste_descriptors)

wine_df_vecs = pd.concat([wine_df_merged_filtered, review_descriptors_df, review_vecs_df], axis=1)
wine_df_vecs.head(5)
# Out:
# aroma
# weight
# sweet
# acid
# salt
# piquant
# fat
# bitter
#                                                title      Variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)  White Blend
# 1                 Tenuta delle Terre Nere 2007  Etna  White Blend
# 2      Cantine Valenti 2015 Enrico IV Bianco  (Etna)  White Blend
# 3  Contrada Santo Spirito di Passopisciaro 2012 A...  White Blend
# 4  Firriato 2009 Cavanera Ripa di Scorciavacca  (...  White Blend
#
#                   geo_normalized  \
# 0  Sicily, Southern Italy, Italy
# 1  Sicily, Southern Italy, Italy
# 2  Sicily, Southern Italy, Italy
# 3  Sicily, Southern Italy, Italy
# 4  Sicily, Southern Italy, Italy
#
#                                          description  \
# 0  Aromas include tropical fruit, broom, brimston...
# 1  This is a mineral-driven wine from the blacken...
# 2  Delicate scents of white flower, flint and whi...
# 3  Subdued aromas of Spanish broom and brimstone ...
# 4  Cavanera is a white blend produced by one of t...
#
#                                    aroma_descriptors weight_descriptors  \
# 0  [tropical_fruit, fruit, herb, apple, citrus, s...                 []
# 1                    [mineral, pear, peach, jasmine]                 []
# 2  [white_flower, flint, stone, fruit, unripe, pe...                 []
# 3                   [apple, citrus_peel, minerality]                 []
# 4                                       [minerality]                 []
#
#   sweet_descriptors                   acid_descriptors salt_descriptors  \
# 0        [dry, dry]                        [high_acid]               []
# 1                []                                 []               []
# 2                []  [high_acid, high_acid, high_acid]               []
# 3                []                        [high_acid]               []
# 4             [dry]             [high_acid, high_acid]               []
#
#   piquant_descriptors fat_descriptors bitter_descriptors  \
# 0                  []              []                 []
# 1                  []              []                 []
# 2                  []              []                 []
# 3                  []              []                 []
# 4                  []              []                 []
#
#                                                aroma weight  \
# 0  [2.0234935, -0.26817894, 2.7913525, -7.105846,...    NaN
# 1  [0.9331111, -3.00844, 4.531299, -9.727131, 6.2...    NaN
# 2  [2.8463452, -3.3319855, 3.8698688, -6.294742, ...    NaN
# 3  [3.2716115, -3.0502708, 5.912527, -6.5354977, ...    NaN
# 4  [3.5302823, 0.44590807, 6.1244144, -6.750567, ...    NaN
#
#                                                sweet  \
# 0  [0.13942882, -1.8551763, 1.710772, -3.8352144,...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  [0.13942882, -1.8551763, 1.710772, -3.8352144,...
#
#                                                 acid  salt piquant  fat  \
# 0  [-0.06676228, -0.87576926, -1.0497628, -0.4488...   NaN     NaN  NaN
# 1                                                NaN   NaN     NaN  NaN
# 2  [-0.06676228, -0.8757693, -1.0497628, -0.44886...   NaN     NaN  NaN
# 3  [-0.06676228, -0.87576926, -1.0497628, -0.4488...   NaN     NaN  NaN
# 4  [-0.06676228, -0.87576926, -1.0497628, -0.4488...   NaN     NaN  NaN
#
#    bitter
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
print(wine_df_vecs.shape)
print(wine_df_vecs['aroma'].isnull().sum(axis = 0))
# Out:
# (29373, 20)
# 139

# %% [markdown]
# If there is not a nonaroma embedding for one of the wines, take the average nonaroma embedding for all the wines in the dataset.

# %%
# pull the average embedding for the wine attribute across all wines. 
avg_taste_vecs = dict()
for k in core_tastes:
    # look at the average embedding for a taste, across all wines that have descriptors for that taste 
    review_arrays = wine_df_vecs[k].dropna()
    average_taste_vec = np.average(review_arrays)
    avg_taste_vecs[k] = average_taste_vec

# %%
avg_taste_vecs
# Out:
# {'aroma': array([ 0.81392586, -2.4280865 ,  3.3803036 , -5.6719713 ,  0.50349313,
#         -1.085401  ,  0.47793332, -1.4958851 ,  0.44697052,  0.93451875,
#          2.8767602 ,  5.579465  ,  0.52665836, -1.3484944 ,  0.56253725,
#          1.1931461 , -0.8177047 , -1.7281162 , -0.12070356,  0.89030814,
#          3.0349307 ,  0.43837   ,  5.239982  ,  2.0910823 ,  0.399469  ,
#         -0.73639476,  4.130707  , -1.4159293 , -1.1690022 ,  0.16318634,
#         -1.8165119 , -3.0381386 , -0.83788747, -0.6672929 ,  4.683531  ,
#          3.0057762 , -0.07149196, -1.8383843 , -1.9233437 , -2.1461124 ,
#         -0.8083863 , -3.370956  , -3.6041806 ,  2.9414213 ,  0.55599684,
#         -0.660081  ,  2.3295577 , -1.0785248 , -0.39634427, -0.23678061,
#         -0.97342014,  1.3977376 , -0.6915297 , -2.9769847 ,  2.7327397 ,
#          2.1818762 ,  1.8410211 , -2.0737739 ,  3.0057352 ,  0.15505809,
#          0.8134393 ,  0.5814624 , -0.58185554, -3.1508656 ,  2.521926  ,
#         -0.9575736 ,  1.3087318 , -2.149622  , -3.565965  , -0.4342538 ,
#         -0.6706501 , -0.13138291,  2.7993627 ,  0.7069901 , -0.9134556 ,
#          1.2074039 ,  1.4634702 ,  1.3679422 ,  1.9223821 ,  0.4101567 ,
#          3.1756656 , -0.39778727,  0.23977695, -0.11277065,  0.07493241,
#         -0.95391786, -1.7900593 , -1.1388751 , -2.4174287 ,  0.78075355,
#          3.4695241 ,  1.4243348 ,  3.3057075 ,  1.4969208 , -2.1673732 ,
#         -2.0641947 , -0.22621907, -1.8736992 ,  1.0000528 , -3.1606822 ,
#          0.93594056,  2.1821778 , -2.2505536 ,  1.6470202 , -0.73223484,
#         -1.9184967 ,  2.3803647 , -1.9013441 ,  1.1069089 , -0.44442666,
#          2.0886137 ,  2.387449  ,  1.6619068 , -0.15361154, -0.9178335 ,
#          2.2235096 , -0.22082615,  1.7975582 ,  2.2505639 ,  3.5838726 ,
#          0.26354942,  0.8332726 ,  2.5819225 , -1.2810441 , -0.5605593 ,
#          0.8913884 , -3.3911762 , -1.8234171 , -1.3107629 ,  0.08644971,
#         -1.300262  , -0.555192  , -3.5606866 ,  0.78579587, -1.9140834 ,
#          1.5424927 , -1.5270485 , -0.90129954, -1.421199  , -4.9807506 ,
#         -0.45914435, -3.4777524 , -0.60131586, -0.30708134,  3.6181774 ,
#          2.0448792 , -0.12703307, -3.8018746 , -2.9532087 ,  3.1581259 ,
#         -5.4311304 ,  2.6994884 , -2.3115685 , -0.991065  , -1.8330363 ,
#         -1.4562335 ,  0.71891403, -2.494358  ,  0.72529024, -4.4092197 ,
#         -1.8946918 ,  1.8902079 , -1.2932198 ,  3.8360207 , -4.2846065 ,
#          0.7243565 ,  3.5034897 , -0.96430826, -1.1157763 ,  1.1370614 ,
#         -4.3378863 ,  0.65736985, -0.3345241 , -0.4191641 , -2.705039  ,
#         -0.7188589 , -3.6814039 , -2.6422591 ,  0.17148952, -2.8733761 ,
#         -1.0959909 ,  0.45968297, -0.6851165 ,  2.2131693 ,  6.1784973 ,
#          1.7119769 , -3.5064037 , -0.8604896 ,  2.5492527 ,  0.15024513,
#         -1.0142419 , -3.9358003 , -1.7850176 , -1.8266313 ,  1.2058766 ,
#         -0.26975814, -2.2446148 ,  1.7408103 ,  3.032424  , -3.378002  ,
#          2.3669503 ,  0.7029561 , -1.0520569 ,  0.21948057, -0.9497405 ,
#         -0.78085214,  0.31039575, -0.7249254 , -1.4846096 , -4.7117705 ,
#          0.7680849 , -1.701548  , -2.6733954 ,  5.756168  , -1.739514  ,
#          1.1576009 , -0.52335876,  1.6725074 ,  3.1022792 , -1.9092761 ,
#         -2.7608888 , -1.0177158 , -0.5453081 , -1.8643601 ,  0.8193627 ,
#          1.5516164 ,  4.3531795 ,  0.0891917 , -0.96098673,  1.1172941 ,
#         -0.40855736, -2.2756202 ,  1.0547037 , -5.424917  , -3.4655817 ,
#         -0.05688746,  2.8602731 ,  0.12158286, -0.5340863 ,  0.66445845,
#         -2.635819  ,  2.271482  , -0.46441785, -2.6632237 ,  4.650167  ,
#          1.3913583 ,  2.307828  ,  2.9042115 , -2.0838504 ,  3.1906848 ,
#          2.0803113 , -0.35667554,  1.1245965 , -3.751935  , -0.6536083 ,
#          2.2239053 , -1.371378  ,  1.77462   ,  0.24718082, -1.0966005 ,
#          0.6781352 , -0.37374437,  1.8187973 ,  0.88772136, -2.2643125 ,
#         -4.0215116 ,  1.2016944 ,  2.9528708 ,  3.763779  , -2.770899  ,
#          1.2088039 , -0.93428814, -2.7507875 , -3.6372871 ,  2.6247509 ,
#         -2.1557057 , -1.2583168 , -1.7491636 ,  0.40593517,  2.2479963 ,
#          4.6410193 , -0.13968769,  1.1937166 , -1.8314426 ,  1.2385807 ,
#         -0.07581826,  0.09901676, -1.6991704 ,  2.3863473 ,  0.6373412 ,
#         -1.6125581 ,  1.0366585 ,  4.6723    ,  0.13868006,  0.7847833 ,
#         -1.4375285 ,  1.7021819 , -1.2101707 ,  1.395098  , -5.3970766 ],
#        dtype=float32),
#  'weight': array([-1.9974624 , -3.3263795 ,  1.543448  , -3.2887304 , -2.0868475 ,
#         -1.8247954 ,  0.7008062 , -1.1222603 ,  0.3471614 , -0.10190824,
#          3.1133502 ,  3.721975  ,  3.5002167 , -2.9816551 , -2.0346572 ,
#          2.3634784 , -0.9565527 , -0.00765042, -0.7552459 , -0.52252865,
#          1.2385745 , -2.03095   ,  1.9877279 ,  0.9907249 ,  1.8280585 ,
#          0.45191246,  0.03216933, -1.1972442 , -0.69793326,  1.6301967 ,
#         -1.2296288 , -1.1082767 , -0.7359814 ,  0.94082147,  2.3029358 ,
#          1.6260184 , -2.5905368 , -1.6052005 , -0.11389212, -4.556337  ,
#         -2.3423555 , -0.59067124, -1.7759899 ,  0.66366327, -1.0279346 ,
#         -2.3086786 ,  1.8834418 , -3.0744972 ,  0.72266364,  3.1624284 ,
#          3.3871043 ,  2.8158836 , -1.1537651 , -2.675143  ,  0.8921985 ,
#         -0.41642943,  1.6015112 , -2.379293  ,  0.8444214 , -0.67004526,
#         -1.3123829 , -0.38864604, -1.5816654 , -2.6504061 ,  2.551858  ,
#          0.7121989 ,  0.55058366,  1.4957088 , -2.8542926 , -0.32828736,
#         -1.6076826 ,  2.1618626 ,  2.2459626 ,  3.2683582 , -0.48116454,
#         -1.4639597 , -0.6904161 ,  1.8729632 ,  2.6883724 ,  1.6419233 ,
#          1.3311579 , -0.39785457,  2.218107  , -1.6459713 , -1.521814  ,
#         -2.5228171 , -2.9585288 , -2.544371  , -0.465098  ,  1.5189224 ,
#          0.41790798,  3.144858  ,  1.6565765 , -0.02632547, -0.2967775 ,
#         -1.5985242 ,  1.2206087 , -1.0818256 , -0.5671424 , -0.62554216,
#          2.7892933 ,  2.4167593 , -2.1894999 ,  0.95560926, -1.2556399 ,
#         -3.9378524 , -1.6925206 , -0.24273513,  0.5286115 , -1.94871   ,
#         -2.0325174 , -2.0008068 ,  0.5713767 ,  1.349281  ,  0.5381807 ,
#         -0.32926425, -1.2846751 ,  4.950963  ,  1.9917445 ,  1.1098778 ,
#          2.7816262 ,  2.2965343 ,  4.397706  ,  3.3066068 , -0.4108075 ,
#          2.368218  , -2.451923  , -0.70091724, -1.7169555 , -1.4212602 ,
#         -1.8774697 ,  1.4478527 , -3.2686799 ,  3.0496259 , -0.17141177,
#         -0.1365413 , -0.9455739 , -0.21600257, -2.6086047 , -1.7362866 ,
#          0.7995599 ,  1.1567036 , -0.6329262 ,  1.7265897 ,  3.6034138 ,
#          2.1031282 , -0.724348  ,  0.02981859,  4.155416  ,  1.3244442 ,
#         -3.0987923 ,  2.8923705 , -1.7665889 , -3.9381726 , -4.478335  ,
#         -2.0597394 ,  1.707722  , -0.9822345 , -0.5026821 , -3.8037121 ,
#         -0.50647676,  3.1404445 ,  0.88868916,  2.402992  , -1.2583008 ,
#          0.2865522 ,  4.437068  , -0.927044  ,  0.5033434 , -0.6448562 ,
#         -1.8086348 , -0.93929994,  0.2950109 ,  2.4781477 , -3.5028834 ,
#          1.3837099 , -1.4706933 , -1.8308647 , -1.0824807 , -2.36144   ,
#         -0.64349955,  1.6873153 , -0.20730925,  3.7206144 ,  3.339622  ,
#          1.3618612 ,  0.24838734,  2.2486768 ,  1.6700124 ,  0.39311567,
#         -2.7594275 , -1.72359   , -0.0152485 ,  0.37048635, -1.5076878 ,
#          0.17393576, -1.0164756 ,  0.3721865 ,  4.2621136 , -3.8859212 ,
#          0.29453683,  1.5424769 ,  0.3619986 ,  2.526799  ,  0.7532674 ,
#          0.4218685 ,  0.03142137,  1.8670505 ,  0.9458391 ,  0.24646668,
#          1.0802615 ,  0.8126767 , -0.74634933,  4.138581  ,  0.4945666 ,
#          1.6349633 , -0.5546857 ,  0.6312967 , -0.08564935,  2.8622017 ,
#          0.79567665,  0.8492678 , -1.7192345 , -2.8030846 ,  0.7321395 ,
#         -0.655365  ,  2.213537  ,  2.1628468 ,  0.86908424,  1.9914922 ,
#          1.9128917 , -0.03082198,  1.573312  , -1.8722397 , -1.7893568 ,
#          2.45298   ,  0.35935658,  0.63808393, -0.17102474, -2.0401862 ,
#         -2.1644828 ,  2.6906054 ,  2.6482463 , -1.2382807 ,  1.9026524 ,
#         -0.93045616, -1.1515422 ,  3.0402148 , -0.67107034,  0.34220955,
#          1.5650227 , -0.50288194,  2.6544433 ,  0.59798247, -0.29466817,
#          2.1189907 ,  0.23741311,  1.2607268 ,  0.14625265, -3.8093326 ,
#         -2.347344  , -0.74886703,  2.4944646 ,  0.7070819 , -0.13442819,
#         -2.4636123 ,  1.2500129 ,  0.7854328 , -0.14060068, -0.13241757,
#          2.8376033 ,  1.0602691 , -0.56417364, -1.3375814 , -0.27479738,
#         -3.3216343 , -2.5931222 , -2.8471026 ,  1.0654645 ,  1.5947088 ,
#          2.1843286 ,  0.96476114, -2.3172596 , -1.5957531 ,  1.2833371 ,
#          2.6772022 , -0.38347328, -0.69306767,  3.8511574 , -0.43971878,
#         -0.10438786,  0.84998226,  2.7461643 ,  0.34851825,  1.3447545 ,
#         -2.0212    , -0.7166068 , -1.9363446 ,  0.32885155, -0.6712802 ],
#        dtype=float32),
#  'sweet': array([ 9.6119148e-01, -1.4861487e+00,  6.4888668e-01, -5.2344236e+00,
#         -2.5732682e+00, -2.1579497e+00,  2.0327113e+00, -2.5748050e+00,
#          2.1050124e+00,  2.2676141e+00,  3.1706648e+00,  3.9620998e+00,
#          6.5571600e-01, -3.6000979e+00,  1.6128639e+00,  6.3225150e-01,
#         -2.2502701e+00,  6.2216640e-01, -2.3721214e-01,  2.7050629e+00,
#         -3.7980809e+00,  1.5591581e+00,  4.2141361e+00,  2.5025220e+00,
#          8.8904601e-01, -2.8587458e-01,  7.2857153e-01, -3.0344949e+00,
#         -2.3778045e+00, -1.5157259e+00, -8.9969349e-01, -4.2079139e+00,
#         -1.9653914e+00, -3.9568191e+00,  4.7300949e+00,  1.3870543e+00,
#         -2.5914350e+00,  8.8154483e-01, -3.2786257e+00, -4.1445417e+00,
#         -4.0570420e-01, -3.8933423e+00, -4.0400639e+00,  2.6160119e+00,
#          3.5132394e+00,  1.8900739e-02,  1.3462586e+00, -2.3183095e+00,
#          1.8484073e+00,  8.2343221e-01,  3.3623655e+00,  3.0589805e+00,
#         -3.7412126e+00, -5.3347387e+00,  2.4314942e+00,  1.9506273e+00,
#          1.4644387e+00,  9.2537868e-01,  1.3745275e+00, -2.1903279e+00,
#         -1.8617566e-01,  3.9858952e+00, -4.5456471e+00, -2.9024928e+00,
#          5.5372415e+00, -2.7819161e+00,  1.0159810e-01,  1.5150837e+00,
#         -1.0349137e+00,  1.3414235e+00, -1.5410060e+00, -1.8598568e+00,
#          2.8465927e+00,  3.1786535e+00,  1.1339612e+00,  1.5889196e+00,
#         -1.6867843e+00,  1.8894073e+00,  4.6167712e+00,  3.9332960e+00,
#          4.3646011e+00,  1.3307528e+00,  4.7953096e-01, -7.8186029e-01,
#         -1.6742882e+00,  3.1105366e+00, -3.2754855e+00, -3.7030139e+00,
#         -2.7644525e+00,  4.1882300e+00,  2.6316521e+00,  2.3901844e+00,
#          6.7044282e+00,  2.2997744e+00, -4.7139354e+00, -2.4484539e+00,
#         -2.7822466e+00, -5.0730176e+00, -9.8442048e-01, -2.0866189e+00,
#         -1.6470516e+00,  3.1609824e+00, -3.4319241e+00,  1.6379712e+00,
#         -3.8556857e+00, -4.3455167e+00,  2.6343992e+00, -2.0004544e+00,
#         -7.1125251e-01,  4.8471209e-01, -6.4207321e-01,  1.3083410e+00,
#          3.7581556e+00,  4.5689052e-01, -1.0075411e+00, -7.7167028e-01,
#          1.2348813e+00,  5.4925103e+00,  4.4440603e+00,  7.7381361e-01,
#          1.8252286e+00,  5.1294196e-01,  1.7354308e+00, -1.3376038e-01,
#         -1.5070283e+00, -2.3954934e-01, -3.0595233e+00,  2.0794961e+00,
#          1.4760013e+00, -8.0247408e-01, -1.4670320e+00, -4.8658930e-02,
#         -2.9654708e+00,  1.8078764e-01, -4.8983118e-01, -2.6517287e-01,
#         -1.2007407e+00,  7.7725089e-01, -1.9193082e+00, -2.1759381e+00,
#          2.4805086e+00, -3.0804020e-01, -9.7631443e-01,  3.9462200e-01,
#          3.2234583e+00, -2.9720712e+00, -2.7986302e+00, -1.2017781e+00,
#         -9.1104364e-01,  2.5165043e+00, -6.4667511e+00,  7.8162533e-01,
#          7.1836907e-01,  2.5727341e+00, -2.3529136e+00, -6.6271415e+00,
#          8.0397016e-01, -3.2614467e+00,  1.4803996e+00, -3.2851000e+00,
#         -2.7425916e+00,  2.0970511e+00, -1.1570039e+00,  6.5680156e+00,
#          7.2832692e-01,  3.1381681e+00,  5.3927941e+00, -5.4555506e-01,
#         -1.5974015e+00,  1.4808736e+00, -3.7118623e+00, -1.9176037e+00,
#          2.9562106e+00,  5.4250962e-01, -1.4526724e+00,  1.4095005e+00,
#         -6.3978467e+00,  1.0193963e+00, -2.7542226e+00,  1.4358549e+00,
#          8.2754683e-01,  2.1603787e+00, -3.6007769e+00,  7.0080318e+00,
#          3.6876240e+00,  4.4696602e-01, -3.8630493e+00,  2.4004366e+00,
#         -1.1209216e+00, -1.1720401e+00, -2.5833461e+00, -4.8607183e+00,
#          3.2208666e-02,  8.9345860e-01, -2.5261481e+00, -8.2417965e-01,
#         -1.0965685e+00,  1.6943794e+00,  5.8509951e+00, -1.7133732e+00,
#         -3.6739933e+00,  1.2917982e-01,  4.8866948e-01,  3.0971773e+00,
#         -5.2335709e-01, -9.2704624e-01,  3.2087545e+00, -2.4294007e-01,
#         -3.4768277e-01, -2.5216548e+00, -2.6484445e-01,  2.0535045e+00,
#         -3.8098598e-01,  3.8992593e+00, -2.0087481e+00,  5.8477535e+00,
#         -5.5403978e-01,  1.8800890e+00,  2.3041506e+00, -9.1572160e-01,
#          1.0183815e+00,  9.8852581e-01,  2.1907225e+00, -1.7415729e+00,
#          2.8006475e+00, -2.1781247e+00,  1.4364395e+00,  3.8906484e+00,
#         -1.2482642e+00,  3.4661696e+00,  6.4517426e-01,  1.7962593e-01,
#         -2.0306127e+00, -3.2174835e+00, -4.3270388e+00,  3.0526450e+00,
#          2.1437376e+00, -1.1775720e+00, -3.8419567e-02,  1.5795854e+00,
#         -9.6543330e-01,  3.8711088e+00, -8.6065555e-01,  1.0624384e+00,
#          3.6743641e+00,  9.1559388e-02,  2.7899461e+00,  1.5389674e+00,
#          4.6992776e-01,  2.8969412e+00,  2.7395654e+00, -4.2655921e-01,
#          1.4629830e+00, -1.8602902e+00,  3.2535505e+00, -4.9725035e-01,
#          5.2850080e-01,  2.0904784e+00, -3.1582010e+00, -2.1432650e+00,
#          8.0600542e-01,  2.6314752e+00,  1.6292839e+00, -7.0511436e-01,
#         -2.5899949e+00, -5.3752750e-01,  1.6127341e+00,  2.7509990e+00,
#         -1.5392456e+00, -3.4413524e-03,  2.0009489e+00, -4.3478084e+00,
#         -4.2699881e+00, -1.6544014e+00,  5.8163259e-02, -3.8495630e-01,
#         -7.4563771e-01, -2.1956620e+00, -1.1037685e+00,  1.3255801e+00,
#          6.3458796e+00,  1.1897109e+00, -5.7440210e-02, -4.4552252e-01,
#          7.4859327e-01,  2.7676449e+00, -2.2683637e+00,  1.2189602e+00,
#          2.5691323e+00, -3.5737532e-01, -1.6628599e-01,  2.3032217e+00,
#          4.9447551e+00,  5.0851744e-01, -2.4900949e+00,  4.1901013e-01,
#          2.2039566e+00, -4.1671604e-01, -1.8238564e-01, -2.4154429e+00],
#        dtype=float32),
#  'acid': array([-4.0608916e-02, -7.7435666e-01, -1.0896016e+00, -5.6305939e-01,
#          1.0162076e+00,  1.1618311e+00,  1.0007303e-01,  1.2723819e+00,
#         -1.6359448e-02,  9.1379148e-01,  9.9051172e-01, -2.2125144e-01,
#          5.9816629e-01,  1.0709506e+00, -1.2151920e+00,  2.1274218e-01,
#          3.5181165e-01, -2.5726280e-01, -3.4637946e-01, -1.3174350e+00,
#         -1.2502168e+00,  5.7768673e-01,  2.7214651e+00, -4.8791370e-01,
#          3.0971065e-01, -1.1351782e+00, -1.1040704e+00, -5.0581282e-01,
#          4.6069178e-01, -6.2371206e-02,  1.2386955e+00, -1.9098070e+00,
#         -8.7748057e-01,  2.9627386e-01, -2.4017714e-01,  1.2897027e-01,
#         -9.1935831e-01,  1.2966789e+00,  5.1117790e-01, -9.5764989e-01,
#          6.6776079e-01,  7.6327258e-01, -6.5233332e-01, -1.4455205e+00,
#         -1.0082284e+00, -2.4702021e-01,  1.0156273e+00, -1.1621802e+00,
#         -9.2729318e-01,  2.3055562e-01,  8.5265487e-01, -1.2964183e+00,
#         -6.1727381e-01, -1.2116995e+00, -8.6614239e-01, -1.1728181e-01,
#         -1.1456488e+00, -2.0179677e+00, -1.2916197e+00,  4.8943579e-01,
#         -4.0695015e-01, -2.3466170e-01, -5.8499795e-01, -3.7669304e-01,
#         -1.2898110e-01,  9.5200342e-01,  1.1915884e-02, -2.0556217e-01,
#         -3.3826572e-01, -1.7250968e+00, -1.6044296e+00, -4.4732037e-01,
#         -7.2814918e-01,  7.1821064e-01, -8.6895722e-01,  6.9652021e-01,
#          6.0045171e-01,  1.3906494e+00,  7.1321917e-01,  7.1636438e-01,
#         -1.3836327e+00, -8.9889042e-02,  5.3279108e-01,  2.5094482e-01,
#         -1.7582239e+00,  1.0070227e-03,  6.9846767e-01,  6.9821978e-01,
#         -1.2971987e+00,  9.7008616e-02,  4.0118515e-01,  1.6714662e-01,
#         -6.0004592e-01,  4.8615721e-01,  1.1906962e+00, -1.4779979e-01,
#         -3.7493455e-01,  3.3163318e-01,  1.8565494e-01, -1.0076747e+00,
#          3.1119546e-01,  3.1100711e-01,  1.4889907e+00,  2.1580086e+00,
#          3.2588449e-01,  1.2576805e+00,  4.7506908e-01, -4.3623328e-01,
#         -1.6692604e-01, -1.4140545e+00,  2.3373368e+00, -4.4147395e-02,
#          1.8069306e-01, -1.0327293e-01,  3.8182220e-01, -8.9265659e-02,
#          7.1540171e-01,  7.8029490e-01,  2.4020739e+00, -8.0301017e-01,
#          4.0979245e-01, -8.1501508e-01,  2.1182606e+00, -1.8579867e-01,
#         -1.8845186e+00,  4.2964980e-01, -1.3064523e+00, -3.1992915e-01,
#         -9.6945667e-01, -2.2423153e+00, -1.1446096e+00, -7.4239594e-01,
#         -1.5391860e+00,  2.7697286e-01, -1.3937947e+00, -1.3155760e+00,
#          8.5477643e-03, -4.8077977e-01, -9.4958138e-01, -9.1867226e-01,
#          7.4445672e-02,  5.4263526e-01,  1.3693346e+00,  9.5072305e-01,
#          1.4769201e+00,  8.4780031e-01, -9.1402501e-01,  6.1483699e-01,
#         -2.2014076e-01, -7.9474199e-01, -8.1710261e-01,  5.5270648e-01,
#         -1.3560284e+00,  4.2561072e-01,  2.2902390e-02,  2.0393941e+00,
#          1.2968254e+00, -9.4613296e-01, -1.1435300e-01, -3.6392459e-01,
#         -9.2913443e-01,  1.0951232e+00,  7.0146883e-01, -2.3456880e-01,
#         -1.6560671e+00,  1.2339487e+00,  5.2028108e-01, -6.2283093e-01,
#          1.6699195e-01, -4.3355736e-01, -1.4048834e+00,  8.2249618e-01,
#          7.2494435e-01,  3.6068213e-01, -1.8994484e+00,  1.6229657e+00,
#         -3.2345352e-01, -4.9795142e-01, -1.4631315e-01,  1.2876304e+00,
#         -2.9761067e-01, -2.6191288e-01,  1.0254697e+00,  5.7902191e-02,
#         -1.1854802e+00,  8.3047819e-01,  1.7707934e+00, -1.6717367e-01,
#          1.1799927e+00,  4.7095287e-01,  6.1368477e-01, -1.9329188e-02,
#         -6.5046173e-01, -8.9128155e-01,  1.1018524e-01, -3.8587116e-02,
#          6.4024603e-01, -6.1450315e-01,  4.4309956e-01, -5.8379126e-01,
#          1.0411470e-01, -6.4501631e-01,  8.9117840e-02, -5.9373754e-01,
#         -2.5590401e+00, -4.6260434e-01, -8.9492458e-01, -1.4290638e-02,
#         -4.1651300e-01,  2.6686835e-01,  8.0386889e-01, -1.7765493e+00,
#         -4.9856472e-01,  3.1424773e-01,  1.1241566e+00, -3.2524839e-01,
#         -1.8824620e+00, -8.0862021e-01,  6.0396981e-01,  5.5783562e-02,
#          2.5812826e-01,  5.8830923e-01,  5.2572942e-01, -1.8256238e+00,
#          1.7592509e+00, -3.3982927e-01,  1.3948252e+00,  5.1873946e-01,
#          4.1083673e-01,  1.9423327e+00,  4.0329883e-01,  1.3012141e+00,
#          1.1592348e+00, -9.1738725e-01,  5.8455670e-01,  3.3789706e-01,
#          1.2626204e+00,  1.5551400e+00,  2.6105812e-01,  3.0237824e-01,
#         -7.9126030e-01,  2.8413126e-01,  8.4892072e-02, -1.1674954e+00,
#         -4.5560074e-01, -6.2202252e-02, -3.7336823e-01, -4.7217140e-01,
#          2.4130152e-01,  2.6152232e-01,  9.3977928e-01, -3.8614148e-01,
#          1.1362578e+00,  6.0414004e-01, -1.5179359e+00,  2.8918058e-01,
#          3.4500957e-02, -8.5310668e-01,  7.5361162e-01, -1.7610492e+00,
#         -4.6012610e-01,  5.8811998e-01,  9.8025513e-01,  7.8478843e-01,
#          8.0796182e-01,  1.2642330e-01,  2.6923984e-01, -1.7579573e-01,
#         -5.4388307e-02, -7.0517731e-01,  7.2416091e-01, -2.5133795e-01,
#         -2.0458867e-01, -1.3835950e+00,  9.3004662e-01, -1.1654963e+00,
#         -2.2802849e+00, -2.5705707e+00, -5.0870103e-01, -1.5689864e+00,
#         -7.9899710e-01,  2.6128170e-01, -1.0808712e+00,  9.8834991e-01,
#          1.4801242e+00,  1.5174667e+00,  5.8735240e-01, -3.0867541e-01,
#          5.8736867e-01, -6.1022973e-01, -2.5274665e+00, -3.0105141e-01,
#          1.6774439e+00, -1.0461568e+00,  3.2209570e+00, -2.3006111e-01,
#         -2.4425715e-01, -1.4802132e+00,  1.7536612e+00, -8.4462625e-01],
#        dtype=float32),
#  'salt': nan,
#  'piquant': array([ 1.73970366e+00, -4.07841063e+00,  5.19432163e+00, -2.48471498e+00,
#         -7.82230568e+00, -4.50683117e+00,  2.21780658e+00,  1.71208441e+00,
#          9.05761242e-01,  2.00191402e+00,  3.89445639e+00,  6.53318882e+00,
#         -4.38804722e+00, -1.83235133e+00, -2.05039140e-03,  3.74403834e+00,
#         -3.29747772e+00, -1.83372274e-01,  5.38087320e+00,  9.70779419e-01,
#          5.84884405e+00, -6.46578252e-01,  8.40411568e+00,  1.68407857e+00,
#          4.14683867e+00, -7.52929592e+00,  1.60186672e+00, -1.07982969e+00,
#         -3.58680797e+00,  3.44265290e-02, -3.69302511e+00, -6.07344580e+00,
#          3.06625545e-01, -4.39486217e+00,  3.07665253e+00,  4.75587845e+00,
#         -6.44899666e-01, -3.20663661e-01, -5.63356590e+00, -4.27706671e+00,
#         -6.35545349e+00,  3.18893695e+00, -4.03546238e+00, -1.67803895e+00,
#          2.69677043e+00, -9.77613270e-01, -1.39524722e+00,  3.71328712e+00,
#          3.82507265e-01,  1.70872235e+00, -1.24118038e-01, -6.98634446e-01,
#          2.86845475e-01, -1.22119629e+00,  4.66732359e+00,  4.34213495e+00,
#          5.33892488e+00, -8.00268745e+00,  6.64735651e+00,  5.24339914e+00,
#         -6.29392207e-01,  5.01472473e+00,  1.08121085e+00, -1.04956236e+01,
#          2.47521892e-01,  1.37377596e+00,  5.69921827e+00, -3.82527232e+00,
#         -7.43157446e-01, -4.42708045e-01, -6.51574254e-01,  4.98234797e+00,
#          5.39315760e-01, -9.45581913e-01,  5.40414214e-01,  2.97083163e+00,
#          4.17775202e+00,  1.19230294e+00,  2.42900968e-01, -1.12589574e+00,
#         -1.03444171e+00,  2.50402451e+00,  3.23392081e+00,  4.84893322e+00,
#          1.90478253e+00,  2.74353933e+00, -4.46191454e+00,  3.56149745e+00,
#         -2.76514506e+00, -2.80577445e+00, -1.44330812e+00,  1.35968935e+00,
#          8.22377324e-01,  1.13281935e-01,  2.62049460e+00, -1.14056110e+00,
#         -4.21553993e+00, -8.36257839e+00,  2.95065284e+00, -3.81121898e+00,
#          3.79500341e+00,  8.97269821e+00, -1.28318524e+00,  8.93551159e+00,
#         -7.71678638e+00,  1.55976427e+00,  3.29909027e-01, -6.11970544e-01,
#          2.15575099e+00,  3.78712869e+00,  5.10126400e+00,  5.24895430e+00,
#          5.02928209e+00,  2.76865983e+00,  8.87120187e-01,  4.14092875e+00,
#         -5.27965426e-01,  3.90754199e+00,  2.33333230e+00,  6.28886652e+00,
#         -8.79150510e-01,  1.17106497e+00,  3.15588379e+00, -3.86848736e+00,
#         -5.04402208e+00,  3.76472688e+00, -4.07068729e+00,  4.13874674e+00,
#          2.88916183e+00, -2.53713846e+00, -5.68060923e+00, -3.98601770e+00,
#         -5.91899824e+00,  5.59812367e-01, -6.76050901e+00, -1.03390075e-01,
#          3.95810097e-01, -1.28298253e-01,  3.99219251e+00, -6.05980968e+00,
#         -4.79460430e+00, -4.48802280e+00,  1.94091821e+00,  3.64170766e+00,
#          1.96430635e+00, -1.22979915e+00, -4.49419886e-01,  1.85529935e+00,
#          1.85530186e+00,  4.21254492e+00, -8.16467571e+00,  1.38042772e+00,
#         -1.02741885e+00,  6.98242283e+00,  9.09259737e-01,  4.72095251e+00,
#         -7.11701155e+00,  4.65500402e+00, -2.22314501e+00, -6.20098066e+00,
#         -2.58995473e-01,  2.29829836e+00, -3.82097936e+00,  2.27047324e+00,
#          5.22862494e-01, -2.55404997e+00,  1.39869571e+00,  6.61384344e-01,
#         -3.47975314e-01,  3.22022462e+00, -8.73175526e+00,  1.03717959e+00,
#          1.17236757e+00, -3.61816359e+00,  3.35395360e+00, -1.42999923e+00,
#         -3.38369775e+00, -4.70825577e+00,  1.27045035e+00, -7.64437628e+00,
#          1.33318305e+00, -5.26584911e+00, -4.09374952e+00,  8.00132465e+00,
#          4.21064425e+00,  3.94472194e+00,  4.13376868e-01,  2.89921910e-01,
#         -1.79687068e-01,  4.17808151e+00, -1.34490240e+00, -4.34507799e+00,
#         -6.80594492e+00, -7.55156136e+00, -3.85586953e+00, -1.60058522e+00,
#         -6.84693575e+00,  3.60413641e-01,  2.64588642e+00, -5.86466789e-01,
#          6.54570580e-01, -1.56060517e+00, -2.14897060e+00,  3.75722194e+00,
#          3.58042216e+00, -4.30830896e-01,  7.41035509e+00,  1.28616691e-02,
#         -5.87475300e+00, -4.48641443e+00,  2.71693897e+00, -5.36733985e-01,
#         -3.42134333e+00,  7.75801182e+00, -8.76729667e-01, -1.44121659e+00,
#         -6.40725136e+00, -2.06494117e+00,  5.43192196e+00, -2.23973408e-01,
#         -2.62793016e+00, -1.68413866e+00, -1.03172076e+00, -7.93745184e+00,
#          6.99578047e-01,  1.12444293e+00,  5.20696115e+00, -3.49545431e+00,
#         -3.75715137e+00, -1.34925824e-02,  1.58055401e+00, -2.80516237e-01,
#          4.70678091e+00, -6.02715063e+00, -6.06177759e+00,  3.16799736e+00,
#          5.68848312e-01, -4.58595753e+00,  4.68970442e+00,  2.22004914e+00,
#         -1.41327786e+00,  1.39941502e+00,  2.01776958e+00, -1.72998405e+00,
#          3.65635085e+00, -2.95946646e+00,  8.89128017e+00,  6.30375719e+00,
#          2.94277072e+00,  2.00044060e+00,  5.46414566e+00,  3.27088666e+00,
#         -1.84830201e+00, -6.64667034e+00, -4.36685419e+00, -3.22373629e-01,
#          2.85395414e-01,  2.68882322e+00, -1.60573125e+00,  2.19691133e+00,
#          2.74473619e+00, -1.29028285e+00,  4.10900450e+00,  2.88915849e+00,
#         -3.12695360e+00, -3.04977489e+00,  5.86405993e+00,  6.19214773e+00,
#         -1.18926942e-01,  1.22119129e+00,  2.62511921e+00, -3.66445971e+00,
#          2.67037416e+00,  1.39282310e+00,  9.84037519e-01, -1.74761128e+00,
#         -2.78968763e+00, -4.21032381e+00, -7.53712225e+00,  3.73632669e+00,
#          3.61621165e+00,  1.37578511e+00, -8.62062335e-01, -2.07328820e+00,
#          9.99529839e-01,  1.88203895e+00,  6.33002090e+00,  8.21872413e-01,
#         -1.79167616e+00,  1.79004228e+00,  6.41386604e+00,  1.18800759e+00,
#          1.82569420e+00,  2.27767038e+00,  1.62232029e+00, -2.12699580e+00,
#          5.75440049e-01, -3.67628098e-01,  4.97355556e+00, -7.94999599e+00],
#        dtype=float32),
#  'fat': array([-2.8476992e+00,  8.4752703e-01, -4.2762766e+00, -3.2498510e+00,
#         -1.4694810e+00, -2.8574641e+00,  2.4695575e+00, -4.1665096e+00,
#         -2.0261710e+00,  5.9000626e+00,  2.3077869e+00,  7.8808790e-01,
#         -2.8322586e-01, -2.8352678e+00, -1.6779641e+00, -8.7570471e-01,
#         -1.8920865e+00,  5.0830454e-01, -3.1069422e+00, -3.9532575e-01,
#          2.7792594e+00, -1.5566210e+00, -1.6562315e+00,  2.2787626e+00,
#         -4.8585632e-01, -3.7572968e+00,  2.0312619e+00,  4.6019113e-01,
#         -3.4356579e-01, -9.7817451e-01,  2.5134776e+00, -3.5512607e+00,
#         -2.9890943e+00,  4.0194993e+00,  3.9198909e+00, -2.1785749e-01,
#         -1.1916509e+00, -2.6744726e+00,  1.7279530e+00, -1.9767548e+00,
#         -3.9545655e+00, -3.4272768e+00, -1.1157460e+00, -3.0948920e+00,
#         -1.9055682e+00, -3.1645913e+00,  1.8182895e+00, -1.8869798e+00,
#          4.3086559e-01,  1.3632591e+00, -9.8888540e-01, -3.4756229e+00,
#         -2.7427197e+00,  6.0863942e-01,  1.3293219e+00,  5.9880223e+00,
#         -3.3447239e+00, -8.1701863e-01,  1.3902116e+00,  2.6030904e-01,
#          1.0764104e+00,  7.7902908e+00, -9.8584032e-01,  1.6855323e+00,
#         -6.5713786e-02,  5.3314286e-01,  1.4744351e+00,  3.1695559e+00,
#          4.2325988e-01, -1.8293449e+00, -2.0288594e+00,  1.4207268e+00,
#          2.9522663e-01, -1.6632004e-01,  8.8363998e-02, -3.6844745e-01,
#          7.9492944e-01,  1.0031494e+00,  4.8056645e+00, -2.8397071e+00,
#          2.5757236e+00, -1.8762850e+00,  1.6667483e+00,  3.4071109e+00,
#         -5.8404889e+00, -2.8457053e+00, -4.9111114e+00, -2.3388128e+00,
#         -9.6792209e-01, -1.2158185e+00,  2.5337009e+00,  2.5775990e+00,
#          2.9691057e+00,  1.4618478e+00, -7.4032366e-01, -5.5790794e-01,
#         -6.1438233e-01,  6.6224355e-01,  1.6043131e+00, -1.1922967e+00,
#         -1.7688704e+00,  1.4575173e-01, -3.9267828e+00,  5.2666202e+00,
#         -1.4131542e+00, -3.0188806e+00, -4.7053707e-01,  3.4018645e+00,
#         -2.1448250e+00, -8.1777912e-01,  3.2143474e+00,  8.7670678e-01,
#          1.2255008e+00,  1.6403615e+00,  2.8860965e+00, -2.0893435e+00,
#          8.3606726e-01,  1.1827205e+00,  5.3704095e+00,  1.1946813e+00,
#          1.3854984e+00, -1.6222502e+00,  1.6018080e+00,  1.6075468e-01,
#         -5.9508849e-02, -3.0029399e+00,  8.4963971e-01,  1.0839616e+00,
#          4.5544323e-01, -9.1642983e-02, -2.8488126e+00,  6.2763733e-01,
#          9.2177951e-01, -3.0133139e-02, -3.5040233e+00,  9.8940462e-01,
#         -2.1108541e+00, -8.4982502e-01,  1.2879366e+00, -6.7464465e-01,
#          1.3632623e+00, -2.4718754e+00, -1.0304247e+00, -7.3375434e-01,
#          2.7488828e+00,  1.4611818e+00,  1.6899225e+00, -9.2480636e-01,
#          3.0846059e+00, -9.8693645e-01,  6.2843001e-01,  3.6781943e+00,
#         -2.0297372e+00,  1.4577638e+00, -5.7031161e-01,  2.5092871e+00,
#         -3.5263650e+00, -4.1186228e+00,  4.3243057e-01,  2.4825439e-01,
#         -4.8912649e+00,  3.6795547e+00, -4.6474614e+00,  2.7937620e+00,
#          2.4689019e-02,  4.5655612e-03,  1.0716689e-01, -2.6094236e+00,
#         -1.9367014e+00, -2.9246371e+00, -5.1697093e-01, -5.8959699e-01,
#          4.1369238e-01,  3.0844596e-01, -6.4163170e+00,  7.8268403e-01,
#          7.4622595e-01, -3.9676743e+00,  9.6007466e-01,  4.9406433e-01,
#         -1.1700627e+00, -6.1567312e-01,  2.9173379e+00,  1.6152978e+00,
#         -1.4861029e-01,  7.8100330e-01, -1.7595809e+00, -1.1052482e+00,
#         -8.2966864e-02, -1.4418935e+00,  1.3806862e+00, -3.1829825e-01,
#         -9.6066046e-01,  2.4741113e+00,  1.4649311e+00, -2.0961878e+00,
#          3.4261563e+00,  5.0976310e+00,  2.6314723e-01,  1.5483606e+00,
#         -1.9536568e-01, -1.7063036e+00, -5.5315506e-01,  1.2509971e+00,
#         -2.6152716e+00, -4.0009785e+00, -3.0342698e-01, -2.7617538e+00,
#         -5.0784292e+00, -5.0863214e+00,  7.1687460e-01,  9.7278915e-02,
#         -1.0812932e+00,  2.3149526e+00,  4.7910223e+00, -3.3752891e-01,
#         -6.1461109e-01,  1.1064454e+00,  2.5852618e+00,  5.1147836e-01,
#         -4.1162410e+00,  2.3085804e+00, -8.4391004e-01,  6.8819505e-01,
#         -2.6753409e+00,  1.9186877e+00,  1.0714203e+00,  1.8527699e+00,
#          1.7951658e+00, -1.5629727e+00, -1.3954901e+00,  3.0099025e+00,
#          7.6351619e-01,  8.4988904e-01,  2.0952177e+00,  6.9543386e-01,
#          4.6734967e+00,  3.1342440e+00, -3.4586444e+00,  1.0193855e+00,
#         -4.6767840e+00, -3.5283568e+00,  3.0421605e+00, -3.3734188e+00,
#          2.5088403e+00,  3.7962532e+00,  2.4519880e+00,  1.8652345e-01,
#          5.7258624e-01,  2.5804167e+00,  1.3606712e+00,  1.8169323e-01,
#         -1.5715996e+00, -4.3050475e+00, -1.9910303e+00,  2.6313016e+00,
#          1.9336592e+00, -1.5941585e+00,  2.1953006e+00, -3.7010396e+00,
#          4.8796293e-01, -2.3551962e+00,  6.2364435e-01, -2.3084264e+00,
#          3.7933323e-01, -1.1109321e+00,  1.0634761e+00, -2.6883036e-01,
#          6.7519350e+00,  1.3308152e+00,  1.5083697e+00, -3.8811859e-01,
#         -4.5260262e+00,  2.9136097e+00, -1.3147709e+00, -3.5971754e+00,
#         -6.1590448e-02, -3.6248118e-02, -2.4643557e+00, -1.0070561e+00,
#          4.2986944e-01,  1.8186171e+00,  1.6412641e-01, -2.5989604e+00,
#          5.1318747e-01,  8.9331001e-01, -1.3741744e+00,  1.6235191e+00,
#         -3.3691788e+00,  1.8818915e+00, -2.2928002e+00,  5.0981164e-01,
#          6.7814951e+00, -2.4965827e+00,  4.6841311e+00, -7.8235108e-01,
#         -3.2767284e+00, -2.1867001e+00,  1.7699929e-01, -9.9331087e-01],
#        dtype=float32),
#  'bitter': nan}
